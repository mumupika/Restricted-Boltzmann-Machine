# %%
import numpy as np

np.random.seed(1337)  # for reproducibility
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


from dbn.models import SupervisedDBNClassification

# %%
# Loading dataset
"""
    dictionary:
        imgs: Original images with uint8, 255
        labels: Original labels with int, 0-10.
"""
train_images=np.load('./Train_images_and_labels_array.npz')
train_img,train_labels=train_images['imgs'],train_images['labels']
test_images=np.load('./Test_images_and_labels_array.npz')
test_img,test_labels=test_images['imgs'],test_images['labels']

# %%
# Data scaling
X_train,X_test = (train_img.astype(np.float32) / 255),(test_img.astype(np.float32) / 255)
Y_train,Y_test = train_labels,test_labels
train_size,test_size = X_train.shape[0],X_test.shape[0]
X_train,X_test=np.reshape(X_train,(train_size,-1)),np.reshape(X_test,(test_size,-1))

# %%
# Data change to 
# Training
classifier = SupervisedDBNClassification(hidden_layers_structure=[500,500],
                                         learning_rate_rbm=0.05,
                                         learning_rate=0.1,
                                         n_epochs_rbm=10,
                                         n_iter_backprop=100,
                                         batch_size=32,
                                         activation_function='sigmoid',
                                         contrastive_divergence_iter=3,
                                         dropout_p=0.2)
classifier.fit(X_train[:6000], Y_train[:6000])
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 20.796457
# >> Epoch 2 finished 	RBM Reconstruction error 14.837647
# >> Epoch 3 finished 	RBM Reconstruction error 11.960278
# >> Epoch 4 finished 	RBM Reconstruction error 10.158644
# >> Epoch 5 finished 	RBM Reconstruction error 8.944716
# >> Epoch 6 finished 	RBM Reconstruction error 8.058646
# >> Epoch 7 finished 	RBM Reconstruction error 7.353176
# >> Epoch 8 finished 	RBM Reconstruction error 6.841809
# >> Epoch 9 finished 	RBM Reconstruction error 6.338829
# >> Epoch 10 finished 	RBM Reconstruction error 5.994351
# >> Epoch 1 finished 	RBM Reconstruction error 13.197222
# >> Epoch 2 finished 	RBM Reconstruction error 7.553942
# >> Epoch 3 finished 	RBM Reconstruction error 5.156147
# >> Epoch 4 finished 	RBM Reconstruction error 4.069937
# >> Epoch 5 finished 	RBM Reconstruction error 3.404247
# >> Epoch 6 finished 	RBM Reconstruction error 2.973104
# >> Epoch 7 finished 	RBM Reconstruction error 2.687072
# >> Epoch 8 finished 	RBM Reconstruction error 2.464355
# >> Epoch 9 finished 	RBM Reconstruction error 2.234516
# >> Epoch 10 finished 	RBM Reconstruction error 2.097242
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 1 finished 	ANN training loss 8.514667
# >> Epoch 2 finished 	ANN training loss 4.562548
# >> Epoch 3 finished 	ANN training loss 3.925795
# >> Epoch 4 finished 	ANN training loss 3.524667
# >> Epoch 5 finished 	ANN training loss 3.321842
# >> Epoch 6 finished 	ANN training loss 3.245101
# >> Epoch 7 finished 	ANN training loss 3.046754
# >> Epoch 8 finished 	ANN training loss 2.869892
# >> Epoch 9 finished 	ANN training loss 2.870165
# >> Epoch 10 finished 	ANN training loss 2.762975
# >> Epoch 11 finished 	ANN training loss 2.717515
# >> Epoch 12 finished 	ANN training loss 2.670311
# >> Epoch 13 finished 	ANN training loss 2.592547
# >> Epoch 14 finished 	ANN training loss 2.516443
# >> Epoch 15 finished 	ANN training loss 2.472257
# >> Epoch 16 finished 	ANN training loss 2.408772
# >> Epoch 17 finished 	ANN training loss 2.404762
# >> Epoch 18 finished 	ANN training loss 2.307510
# >> Epoch 19 finished 	ANN training loss 2.345849
# >> Epoch 20 finished 	ANN training loss 2.304288
# >> Epoch 21 finished 	ANN training loss 2.239708
# >> Epoch 22 finished 	ANN training loss 2.257751
# >> Epoch 23 finished 	ANN training loss 2.126652
# >> Epoch 24 finished 	ANN training loss 2.178438
# >> Epoch 25 finished 	ANN training loss 2.126905
# >> Epoch 26 finished 	ANN training loss 2.048244
# >> Epoch 27 finished 	ANN training loss 2.038457
# >> Epoch 28 finished 	ANN training loss 2.040065
# >> Epoch 29 finished 	ANN training loss 1.996397
# >> Epoch 30 finished 	ANN training loss 1.975859
# >> Epoch 31 finished 	ANN training loss 1.988348
# >> Epoch 32 finished 	ANN training loss 1.881048
# >> Epoch 33 finished 	ANN training loss 1.959545
# >> Epoch 34 finished 	ANN training loss 1.862942
# >> Epoch 35 finished 	ANN training loss 1.876074
# >> Epoch 36 finished 	ANN training loss 1.811187
# >> Epoch 37 finished 	ANN training loss 1.831372
# >> Epoch 38 finished 	ANN training loss 1.838823
# >> Epoch 39 finished 	ANN training loss 1.797430
# >> Epoch 40 finished 	ANN training loss 1.799391
# >> Epoch 41 finished 	ANN training loss 1.823241
# >> Epoch 42 finished 	ANN training loss 1.692071
# >> Epoch 43 finished 	ANN training loss 1.718876
# >> Epoch 44 finished 	ANN training loss 1.685446
# >> Epoch 45 finished 	ANN training loss 1.670039
# >> Epoch 46 finished 	ANN training loss 1.587566
# >> Epoch 47 finished 	ANN training loss 1.692032
# >> Epoch 48 finished 	ANN training loss 1.617910
# >> Epoch 49 finished 	ANN training loss 1.612937
# >> Epoch 50 finished 	ANN training loss 1.619448
# >> Epoch 51 finished 	ANN training loss 1.581160
# >> Epoch 52 finished 	ANN training loss 1.554497
# >> Epoch 53 finished 	ANN training loss 1.616925
# >> Epoch 54 finished 	ANN training loss 1.634321
# >> Epoch 55 finished 	ANN training loss 1.528979
# >> Epoch 56 finished 	ANN training loss 1.595196
# >> Epoch 57 finished 	ANN training loss 1.476557
# >> Epoch 58 finished 	ANN training loss 1.517128
# >> Epoch 59 finished 	ANN training loss 1.522408
# >> Epoch 60 finished 	ANN training loss 1.530345
# >> Epoch 61 finished 	ANN training loss 1.505198
# >> Epoch 62 finished 	ANN training loss 1.476400
# >> Epoch 63 finished 	ANN training loss 1.437163
# >> Epoch 64 finished 	ANN training loss 1.437943
# >> Epoch 65 finished 	ANN training loss 1.442470
# >> Epoch 66 finished 	ANN training loss 1.496151
# >> Epoch 67 finished 	ANN training loss 1.356858
# >> Epoch 68 finished 	ANN training loss 1.418184
# >> Epoch 69 finished 	ANN training loss 1.427440
# >> Epoch 70 finished 	ANN training loss 1.368334
# >> Epoch 71 finished 	ANN training loss 1.431123
# >> Epoch 72 finished 	ANN training loss 1.410833
# >> Epoch 73 finished 	ANN training loss 1.353438
# >> Epoch 74 finished 	ANN training loss 1.311958
# >> Epoch 75 finished 	ANN training loss 1.363776
# >> Epoch 76 finished 	ANN training loss 1.328359
# >> Epoch 77 finished 	ANN training loss 1.343768
# >> Epoch 78 finished 	ANN training loss 1.343339
# >> Epoch 79 finished 	ANN training loss 1.291938
# >> Epoch 80 finished 	ANN training loss 1.286992
# >> Epoch 81 finished 	ANN training loss 1.319858
# >> Epoch 82 finished 	ANN training loss 1.297938
# >> Epoch 83 finished 	ANN training loss 1.330707
# >> Epoch 84 finished 	ANN training loss 1.289877
# >> Epoch 85 finished 	ANN training loss 1.315934
# >> Epoch 86 finished 	ANN training loss 1.254067
# >> Epoch 87 finished 	ANN training loss 1.276145
# >> Epoch 88 finished 	ANN training loss 1.222055
# >> Epoch 89 finished 	ANN training loss 1.213713
# >> Epoch 90 finished 	ANN training loss 1.224644
# >> Epoch 91 finished 	ANN training loss 1.231309
# >> Epoch 92 finished 	ANN training loss 1.222707
# >> Epoch 93 finished 	ANN training loss 1.192285
# >> Epoch 94 finished 	ANN training loss 1.186986
# >> Epoch 95 finished 	ANN training loss 1.232831
# >> Epoch 96 finished 	ANN training loss 1.227493

# %%
Y_pred = classifier.predict(X_test[:1000])
print('Done.\nAccuracy: %f' % accuracy_score(Y_test[:1000], Y_pred))
# Out:
# Done.
# Accuracy: 0.400000

# %%
fine_tuning_loss=classifier.fine_tuning_loss
rbm_losses=list()
for rbm in classifier.unsupervised_dbn.rbm_layers:
    rbm_losses.append(rbm.reconstruction_error)
